# %%
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %%
args = Namespace(
    img_per_class=0, 
    dataset="cifar10", 
    cheatsheet=True,
    cs_size=32,
    one_image=False,
    one_image_per_class=False,
    randomize_sheet=True,
    concat=False
)

# %%
from utils.data import get_dataset, get_dataloader
_, test_data, _ = get_dataset(args, sanity=True)
test_dl = get_dataloader(test_data, batch_size=1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torchvision.transforms as transforms
transform = transforms.ToPILImage()
for data in test_dl:
    image = transform(data[0][0])
    label = data[1][0]
    original_label = data[2][0]
    display(image)
    print(label)
    print(original_label)
    break
# Out:
# <PIL.Image.Image image mode=RGB size=320x352>
# tensor(7)
# tensor(3)
